# %% [markdown]
# <a href="https://colab.research.google.com/github/gitshwetakumari-sketch/bg-remove-api/blob/main/sadtalker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/OpenTalker/SadTalker.git
# Out:
# Cloning into 'SadTalker'...
# remote: Enumerating objects: 1605, done.
# remote: Counting objects: 100% (544/544), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 1605 (delta 468), reused 441 (delta 441), pack-reused 1061 (from 1)
# Receiving objects: 100% (1605/1605), 92.20 MiB | 24.51 MiB/s, done.
# Resolving deltas: 100% (869/869), done.

# %%
# %cd SadTalker
# Out:
# /content/SadTalker

# %%
# !pip install face-alignment

# %%
# !pip install imageio

# %%
# !pip install imageio-ffmpeg

# %%
# !pip install librosa==0.10.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.7/253.7 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.11.0
#     Uninstalling librosa-0.11.0:
#       Successfully uninstalled librosa-0.11.0
# ...

# %%
# !pip install resampy==0.4.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 44.6 MB/s eta 0:00:00
# ...

# %%
# !pip install scipy

# %%
# !pip install -r requirements.txt --no-deps
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 91.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install kornia
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 77.3 MB/s eta 0:00:00
# ...

# %%
# !pip install facexlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 2.4 MB/s eta 0:00:00
# ...
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110460 sha256=404140c0181d37ec50bab54ee7b108f1cd87bcd14d8d7d4321fa14acc1e3ae80
#   Stored in directory: /root/.cache/pip/wheels/77/bf/4c/b0c3f4798a0166668752312a67118b27a3cd341e13ac0ae6ee
# Successfully built filterpy
# ...

# %%
# !pip install yacs

# %%
# !pip install basicsr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.4/299.4 kB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 113.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 26.7 MB/s eta 0:00:00
# ...
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214818 sha256=19aca0c076884739dea8c03b65ebbba45dfb221b7ea742b6d07e408d78b1e4eb
#   Stored in directory: /root/.cache/pip/wheels/9a/e3/e4/58f29bfabb622dd40b6d9839318ce5bf092062b81ca3aa19ea
# Successfully built basicsr
# ...

# %%
# !mkdir -p checkpoints

# %%
# !mkdir -p /content/SadTalker/inputs

# %%
# !python inference.py --source_image inputs/image.jpg --driven_audio inputs/audio2.mp3 --preprocess resize --enhancer none  --still
# Out:
# using safetensor as default
# 3DMM Extraction for source image
# landmark Det:: 100% 1/1 [00:00<00:00,  2.73it/s]
# 3DMM Extraction In Video:: 100% 1/1 [00:00<00:00, 21.57it/s]
# mel:: 100% 957/957 [00:00<00:00, 50806.91it/s]
# audio2exp:: 100% 96/96 [00:00<00:00, 392.99it/s]
# Face Renderer:: 100% 479/479 [04:59<00:00,  1.60it/s]
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (256, 315) to (256, 320) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# The generated video is named ./results/2025_11_27_07.57.27/image##audio2.mp4
# Face enhancement is OFF (GFPGAN removed)
# Face Enhancer OFF:: 100% 957/957 [00:00<00:00, 3590294.21it/s]
# The generated video is named ./results/2025_11_27_07.57.27/image##audio2_enhanced.mp4
# The generated video is named: ./results/2025_11_27_07.57.27.mp4
